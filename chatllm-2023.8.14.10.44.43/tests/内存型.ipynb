# %%
from meutils.pipe import *

from llm.utils import llm_load
from llm.docutils import DocEmbedding
from llm.applications import Question2Answer

# %%
doc_encode = DocEmbedding(device='mps')
t = Path('/Users/betterme/PycharmProjects/AI/LLM4GPT/data/医/古今医统大全.txt').read_text()
texts = t.split('\n') | xfilter_(lambda x: len(x) > 10)
da = doc_encode(texts[:100], show_progress_bar=True, return_document=True)
# Out:
# No sentence-transformers model found with name /Users/betterme/.cache/torch/sentence_transformers/shibing624_text2vec-base-chinese. Creating a new one with MEAN pooling.
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]

# %%
model, tokenizer = llm_load("/Users/betterme/PycharmProjects/AI/CHAT_MODEL/chatglm")
# Out:
# Explicitly passing a `revision` is encouraged when loading a model with custom code to ensure no malicious code has been contributed in a newer revision.
# Explicitly passing a `revision` is encouraged when loading a configuration with custom code to ensure no malicious code has been contributed in a newer revision.
# Explicitly passing a `revision` is encouraged when loading a model with custom code to ensure no malicious code has been contributed in a newer revision.
# Loading checkpoint shards:   0%|          | 0/8 [00:00<?, ?it/s]

# %%
qa = Question2Answer(
    chat_func = partial(model.stream_chat, tokenizer=tokenizer),
#     query_embedd = doc_encode,
#     docs = da
)

# %%
# for i, _ in qa.qa(query='发烧怎么办', topk=3):
#     i
print(i)
# Out:
# 发烧了，可以考虑采取以下措施：
#
# 1. 休息：身体需要休息来帮助身体抵抗感染。如果发烧，最好尽量避免剧烈运动或过度活动。
#
# 2. 喝水：多喝水可以帮助身体保持水分，防止脱水。如果烧得很高，可以尝试喝一些温水或凉饮料。
#
# 3. 降温：可以使用湿毛巾或冰袋来降温。将湿毛巾或冰袋放在额头上，或将其放在膝盖上，帮助降低体温。
#
# 4. 服用药物：如果烧得很高，医生可能会建议服用退烧药。常见的退烧药包括对乙酰氨基酚(泰诺等品牌)或布洛芬(芬必得等品牌)。
#
# 5. 测量体温：最好每天测量体温，以便跟踪进度并确定是否需要进一步采取措施。
#
# 请注意，如果发烧持续时间较长或伴随其他症状，如呼吸急促、咳嗽、腹泻等，请尽快咨询医生。

# %% [markdown]
# # 百度热搜

# %%
qa = Question2Answer(
    chat_func = partial(model.stream_chat, tokenizer=tokenizer),
)

# %%
for i, _ in qa.crawler4qa('五一国内游预订怎么样', print_knowledge_base=True):
    print(i, flush=True)
# Out:
# 2023-04-21 15:22:12.716 | INFO     | meutils.request_utils:request4retry:23 - Try
# ['  用好解决民生问题的“总钥匙” ', '  宝马MINI展台改发钥匙扣 多人排队 ', '  女子吐槽软卧车厢分配3男1女 ', '  五一国内游预订全线超越2019年 ', '  #安以轩老公被判监禁14年# ', '  宝马半个董事会败给冰淇淋 ', '  宝马蒸发市值可买约5亿个冰淇淋 ', '  全民星选高效工作季来啦！ ', '  宝马MINI反问式道歉 能接受么？ ', '  榴莲批发价1斤低至20元 ', '  1.6吨黄金在加拿大机场被盗 ', '  原来兵马俑每天都在挖 ', '  山西暴雪：多地积雪20厘米 ', '  浙大学生因辱华言论被拒录公务员 ', '  秦刚:中国土地收回来就绝不会再失去 ', '  券商回应女生求职被要求跳舞 ', '  贵州遭暴雨袭击：正睡觉房子被吹飞 ', '  史诗级公关灾难 ', '  合肥市委书记暗访 发现安全出口被锁 ', '  日本2040年单身比例将达47% ', '  网友自费买冰淇淋去车展现场发 ', '  夫妻嫌上班赚钱慢拍淫秽视频获刑 ', '  济南海关退运1.8吨旧和服 ', '  73岁徐克现身医院引担忧 ', '  五一假期十大热门城市 ', '  马云被聘为香港大学荣誉教授 ', '  国产带状疱疹疫苗全国接种启动 ', '  官方通报摊主被陌生人贴膏药后晕倒 ', '  深圳二手房贷或将与参考价脱钩 ', '  比亚迪董事长坐地铁去车展 ', '  宝马MINI再道歉：“老外”是同事 ']
# Stream: 0it [00:00, ?it/s]
# 五一
# 五一国内
# 五一国内游
# 五一国内游预订
# 五一国内游预订在
# 五一国内游预订在过去几年
# 五一国内游预订在过去几年中
# 五一国内游预订在过去几年中一直都是
# 五一国内游预订在过去几年中一直都是非常
# 五一国内游预订在过去几年中一直都是非常热门的
# 五一国内游预订在过去几年中一直都是非常热门的，
# 五一国内游预订在过去几年中一直都是非常热门的，因为
# 五一国内游预订在过去几年中一直都是非常热门的，因为假期
# ...

# %%
i
# Out:
# '五一国内游预订在过去几年中一直都是非常热门的，因为假期长、天气好，游客可以在国内享受到放松、度假的感觉。根据目前的天气预报，五一假期期间国内大部分地区都是晴天，气温适宜，非常适合旅游。\n\n不过，需要注意的是，五一假期是旅游旺季，游客数量较多，可能会出现拥堵、排队等状况。因此，在选择旅游地点时，建议提前预订，选择人流量较少的时段出行，避免拥堵和排队等待的情况。同时，还需要注意旅游安全，遵守当地的法律法规和旅游规定。'

# %%
from llm.applications import Question2Answer
from llm.utils import llm_load
from meutils.pipe import *

# %%
model, tokenizer = llm_load("/Users/betterme/PycharmProjects/AI/CHAT_MODEL/chatglm")
# Out:
# Explicitly passing a `revision` is encouraged when loading a model with custom code to ensure no malicious code has been contributed in a newer revision.
# Explicitly passing a `revision` is encouraged when loading a configuration with custom code to ensure no malicious code has been contributed in a newer revision.
# Explicitly passing a `revision` is encouraged when loading a model with custom code to ensure no malicious code has been contributed in a newer revision.
# Loading checkpoint shards:   0%|          | 0/8 [00:00<?, ?it/s]

# %%
qa = Question2Answer(
    chat_func = partial(model.chat, tokenizer=tokenizer),
)

# %%
knowledge_base = """
姚明（Yao Ming），男，汉族，无党派人士，1980年9月12日出生于上海市徐汇区，祖籍江苏省苏州市吴江区震泽镇，前中国职业篮球运动员，司职中锋，现任亚洲篮球联合会主席、中国篮球协会主席、中职联公司董事长兼总经理， [1-3]   十三届全国青联副主席， [4]  改革先锋奖章获得者。 [5]  第十四届全国人大代表 [108]  。
1998年4月，姚明入选王非执教的国家队，开始篮球生涯。2001夺得CBA常规赛MVP，2002年夺得CBA总冠军以及总决赛MVP，分别3次当选CBA篮板王以及盖帽王，2次当选CBA扣篮王。在2002年NBA选秀中，他以状元秀身份被NBA的休斯敦火箭队选中，2003-09年连续6个赛季（生涯共8次）入选NBA全明星赛阵容，2次入选NBA最佳阵容二阵，3次入选NBA最佳阵容三阵。2009年，姚明收购上海男篮，成为上海久事大鲨鱼俱乐部老板。2011年7月20日，姚明宣布退役。
2013年，姚明当选为第十二届全国政协委员。2015年2月10日，姚明正式成为北京申办冬季奥林匹克运动会形象大使之一。2016年4月4日，姚明正式入选2016年奈史密斯篮球名人纪念堂，成为首位获此殊荣的中国人；10月，姚明成为中国“火星大使”；11月，当选CBA公司副董事长。 [6]
2017年10月20日，姚明已将上海哔哩哔哩俱乐部全部股权转让。 [7]  2018年9月，荣获第十届“中华慈善奖”慈善楷模奖项。 [8]  2019年10月28日，胡润研究院发布《2019胡润80后白手起家富豪榜》，姚明以22亿元排名第48。
"""
qa._qa('姚明住哪里', knowledge_base, max_turns=3)
# Out:
# The dtype of attention mask (torch.int64) is not bool
# '姚明住上海。'

# %%
qa.history
# Out:
# [[None, '姚明住上海。']]

# %%
qa._qa('姚明多少岁，主要成就有哪些', knowledge_base, max_turns=3)
# Out:
# '姚明出生于1980年9月12日，于2011年7月20日宣布退役，现年49岁。\n\n姚明的主要成就包括：\n\n1. 2002年NBA选秀状元，被休斯敦火箭队选中；\n2. 职业生涯共8次入选NBA全明星赛阵容；\n3. 2次入选NBA最佳阵容二阵，3次入选NBA最佳阵容三阵；\n4. 2001年夺得CBA常规赛MVP,2002年夺得CBA总冠军以及总决赛MVP;\n5. 分别3次当选CBA篮板王以及盖帽王，2次当选CBA扣篮王；\n6. 收购上海男篮，成为上海久事大鲨鱼俱乐部老板；\n7. 当选为第十二届全国政协委员；\n8. 2016年4月4日，姚明正式入选2016年奈史密斯篮球名人纪念堂，成为首位获此殊荣的中国人；\n9. 成为中国“火星大使”;\n10. 2018年9月，荣获第十届“中华慈善奖”慈善楷模奖项。'
